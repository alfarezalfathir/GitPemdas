# %%
data_panen = {
    'lokasi1': {
        'nama_lokasi': 'Kebun A',
        'hasil_panen': {
            'padi': 1200,
            'jagung': 800,
            'kedelai': 500
        }
    },
    'lokasi2': {
        'nama_lokasi': 'Kebun B',
        'hasil_panen': {
            'padi': 1500,
            'jagung': 900,
            'kedelai': 450
        }
    },
    'lokasi3': {
        'nama_lokasi': 'Kebun C',
        'hasil_panen': {
            'padi': 1100,
            'jagung': 750,
            'kedelai': 600
        }
    },
    'lokasi4': {
        'nama_lokasi': 'Kebun D',
        'hasil_panen': {
            'padi': 1300,
            'jagung': 850,
            'kedelai': 550
        }
    },
    'lokasi5': {
        'nama_lokasi': 'Kebun E',
        'hasil_panen': {
            'padi': 1400,
            'jagung': 950,
            'kedelai': 480
        }
    }
}

# %%
for kode, data in data_panen.items():
    print("Kode Lokasi :", kode)
    print("Nama Lokasi :", data['nama_lokasi'])
    print("Hasil Panen :")
    for tanaman, jumlah in data['hasil_panen'].items():
        print(f" - {tanaman} : {jumlah}")
    print("-" * 30)
# Out:
# Kode Lokasi : lokasi1
# Nama Lokasi : Kebun A
# Hasil Panen :
#  - padi : 1200
#  - jagung : 800
#  - kedelai : 500
# ------------------------------
# Kode Lokasi : lokasi2
# Nama Lokasi : Kebun B
# Hasil Panen :
#  - padi : 1500
#  - jagung : 900
#  - kedelai : 450
# ------------------------------
# Kode Lokasi : lokasi3
# Nama Lokasi : Kebun C
# Hasil Panen :
#  - padi : 1100
#  - jagung : 750
#  - kedelai : 600
# ------------------------------
# Kode Lokasi : lokasi4
# Nama Lokasi : Kebun D
# Hasil Panen :
#  - padi : 1300
#  - jagung : 850
#  - kedelai : 550
# ------------------------------
# Kode Lokasi : lokasi5
# Nama Lokasi : Kebun E
# Hasil Panen :
#  - padi : 1400
#  - jagung : 950
#  - kedelai : 480
# ------------------------------

# %%
data_panen['lokasi2']['hasil_panen']['jagung']
# Out:
# 900

# %%
data_panen['lokasi3']['nama_lokasi']
# Out:
# 'Kebun C'

# %%
padi_lokasi1 = data_panen['lokasi1']['hasil_panen']['padi']
kedelai_lokasi1 = data_panen['lokasi1']['hasil_panen']['kedelai']

padi_lokasi2 = data_panen['lokasi2']['hasil_panen']['padi']
kedelai_lokasi2 = data_panen['lokasi2']['hasil_panen']['kedelai']

padi_lokasi3 = data_panen['lokasi3']['hasil_panen']['padi']
kedelai_lokasi3 = data_panen['lokasi3']['hasil_panen']['kedelai']

padi_lokasi4 = data_panen['lokasi4']['hasil_panen']['padi']
kedelai_lokasi4 = data_panen['lokasi4']['hasil_panen']['kedelai']

padi_lokasi5 = data_panen['lokasi5']['hasil_panen']['padi']
kedelai_lokasi5 = data_panen['lokasi5']['hasil_panen']['kedelai']

padi_lokasi1, kedelai_lokasi1
# Out:
# (1200, 500)

# %%
for data in data_panen.values():
    padi = data['hasil_panen']['padi']
    jagung = data['hasil_panen']['jagung']

    if padi > 1300 or jagung > 800:
        status = "Memerlukan perhatian khusus"
    else:
        status = "Kondisi baik"

    print(f"{data['nama_lokasi']} : {status}")
# Out:
# Kebun A : Kondisi baik
# Kebun B : Memerlukan perhatian khusus
# Kebun C : Kondisi baik
# Kebun D : Memerlukan perhatian khusus
# Kebun E : Memerlukan perhatian khusus

# %% [markdown]
# git init
# git add .
# git commit -m "Commit pertama tugas Git (ipynb)"
# git branch -M main
# git remote add origin https://github.com/USERNAME/TugasGitMandiri.git
# git push -u origin main

# %% [markdown]
# coba cobaa
